# %%
import pickle

# %%
path='EditSQL/data_clean/spider_data_removefrom/'
with (open(path+'dev.pkl', "rb")) as openfile:
    data=pickle.load(openfile)

# %%
data
# Out:
# [{'id': '',
#   'scenario': '',
#   'database_id': 'cre_Doc_Template_Mgt',
#   'interaction_id': 0,
#   'final': {'utterance': 'How many documents do we have ?',
#    'sql': 'select count ( documents.* )'},
#   'interaction': [{'utterance': 'How many documents do we have ?',
#     'sql': [(['select', 'count', '(', 'documents.*', ')'], [])]}]},
#  {'id': '',
#   'scenario': '',
#   'database_id': 'cre_Doc_Template_Mgt',
#   'interaction_id': 1,
#   'final': {'utterance': 'Count the number of documents .',
#    'sql': 'select count ( documents.* )'},
#   'interaction': [{'utterance': 'Count the number of documents .',
#     'sql': [(['select', 'count', '(', 'documents.*', ')'], [])]}]},
#  {'id': '',
#   'scenario': '',
#   'database_id': 'cre_Doc_Template_Mgt',
#   'interaction_id': 2,
#   'final': {'utterance': 'List document IDs , document names , and document descriptions for all documents .',
# ...

# %%
import json
with open(path+'dev_lang.json', 'w') as f:
    json.dump(data, f)

# %%
data[0]['lang']='eng'
data[0]
# Out:
# {'id': '',
#  'scenario': '',
#  'database_id': 'cre_Doc_Template_Mgt',
#  'interaction_id': 0,
#  'final': {'utterance': 'How many documents do we have ?',
#   'sql': 'select count ( documents.* )'},
#  'interaction': [{'utterance': 'How many documents do we have ?',
#    'sql': [(['select', 'count', '(', 'documents.*', ')'], [])]}],
#  'lang': 'eng'}

# %%
for i in range(len(data)):
    data[i]['lang']='eng'

# %%
data
# Out:
# [{'id': '',
#   'scenario': '',
#   'database_id': 'cre_Doc_Template_Mgt',
#   'interaction_id': 0,
#   'final': {'utterance': 'How many documents do we have ?',
#    'sql': 'select count ( documents.* )'},
#   'interaction': [{'utterance': 'How many documents do we have ?',
#     'sql': [(['select', 'count', '(', 'documents.*', ')'], [])]}],
#   'lang': 'eng'},
#  {'id': '',
#   'scenario': '',
#   'database_id': 'cre_Doc_Template_Mgt',
#   'interaction_id': 1,
#   'final': {'utterance': 'Count the number of documents .',
#    'sql': 'select count ( documents.* )'},
#   'interaction': [{'utterance': 'Count the number of documents .',
#     'sql': [(['select', 'count', '(', 'documents.*', ')'], [])]}],
#   'lang': 'eng'},
#  {'id': '',
#   'scenario': '',
#   'database_id': 'cre_Doc_Template_Mgt',
#   'interaction_id': 2,
#   'final': {'utterance': 'List document IDs , document names , and document descriptions for all documents .',
# ...
